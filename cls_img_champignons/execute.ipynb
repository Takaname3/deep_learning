# %%
from fastai.vision import *
import warnings
warnings.filterwarnings('ignore')

# %%
# chargement du model et de ses classes
learn = load_learner(path='models', file='model_fit_champ.pkl')
classes = learn.data.classes

# %%
# renseigner ici l'image se trouvant dans le fichier data (attention l'extension du fichier)
img = open_image('data/trompette.jpg').resize(255)
img
# Out:
# Image (3, 163, 310)

# %%
# prediction 
prediction = learn.predict(img)
classes[prediction[1].item()]
# Out:
# 'trompette_de_la_mort'
